# %% [markdown]
# # Installation

# %% [markdown]
# https://github.com/features/copilot/cli
#
# Open power shell
#
# winget install GitHub.Copilot

# %% [markdown]
# # Commands to Cover

# %% [markdown]
# /login
#
# /help
#
# /init
#
# /clear
#
# /quit & /resume

# %% [markdown]
# ## Usage 1: Get familiar with the codebase
#
# Can you describe the codebase structure for me
#
# What is the RAG pipeline and how it is used
#
# trace the process of handling a user's query from front end to backend
#
# draw a diagram to illustrate the workflow for me. You can use Ascii-style to do it.
#
# how do i run it in windows
